# %% [markdown]
# # Reconstruction Experiment on SSL Models (supervisedVIT)
#
# This notebook adapts the probing experiment framework to focus on 3D voxel reconstruction using `VoxelProbe`. It will:
# - Load a pre-trained supervisedVIT model.
# - Extract features from specified layers.
# - Train `VoxelProbe` instances on these features to predict 3D voxel occupancy.
# - Evaluate performance using IoU, Precision, Recall, and F1-score.
# - Analyze and visualize results to determine which layers are best for reconstruction.

# %% [markdown]
# ### Imports, Logging Setup

# %%
# Set environment variables before imports
import os
os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'

# Imports
import hydra
from omegaconf import DictConfig, OmegaConf
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
from pathlib import Path
import logging
import wandb
from typing import Dict, List, Tuple, Optional
from tqdm import tqdm

# Model and dataset imports
from src.models.reconstruction_feature_extractor import ReconstructionFeatureExtractor, load_image_feature_extractor 
from src.datasets.shapenet_voxel_meshes import create_3dr2n2_reconstruction_dataloaders 

# Probing imports using new modular structure
from src.probing import (
    create_probe, 
    ProbeTrainer,
    ReconstructionPipeline,
    ReconstructionDataset,
    compute_voxel_metrics,
    MetricsTracker,
)
from src.analysis.layer_analysis import LayerWiseAnalyzer

# Fix duplicate logging issue in Jupyter notebooks
# Clear any existing handlers to prevent duplicates
root_logger = logging.getLogger()
for handler in root_logger.handlers[:]:
    root_logger.removeHandler(handler)

# Configure logging fresh
logging.basicConfig(
    level=logging.INFO, 
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    force=True  # This forces reconfiguration in newer Python versions
)

# Get the notebook logger
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Reconstruction Experiment Setup

# %%
class ReconstructionExperiment:
    """Orchestrates 3D reconstruction experiments using VoxelProbes"""

    def __init__(self, config: DictConfig):
        self.config = config
        device_to_use = config.get("device", config.get("device"))
        if device_to_use:
            self.device = device_to_use
        else:
            self.device = (
                "cuda"
                if torch.cuda.is_available()
                else "mps" if torch.backends.mps.is_available() else "cpu"
            )
        logger.info(f"Using device: {self.device}")

        if config.get("wandb", {}).get("enabled", False):
            wandb.init(
                project=config.wandb.project,
                entity=config.wandb.get("entity"),
                name=config.experiment.name + "_reconstruction", 
                config=OmegaConf.to_container(config, resolve=True),
            )

        self.results_dir = Path(config.get("results_dir", "./results")) / (config.experiment.name)
        self.results_dir.mkdir(parents=True, exist_ok=True)
        self.cache_dir = Path(config.get("cache_dir", "./cache")) / (config.experiment.name)
        self.cache_dir.mkdir(parents=True, exist_ok=True)
        
        self.probe_save_dir = self.cache_dir / "probes"
        self.probe_save_dir.mkdir(parents=True, exist_ok=True)
        
        self.analyzer = LayerWiseAnalyzer(self.results_dir)

    def load_source_dataset(self) -> Tuple[DataLoader, DataLoader, DataLoader]:
        """Load the source ShapeNet dataset with images and voxels."""
        subset_percentage = self.config.datasets.get("subset_percentage", None)
        return create_3dr2n2_reconstruction_dataloaders( 
            self.config.datasets, 
            batch_size=self.config.datasets.get("source_batch_size", 16), 
            num_workers=self.config.get("num_workers", 4),
            subset_percentage=subset_percentage
        )

    def load_reconstruction_feature_extractor(self) -> ReconstructionFeatureExtractor:
        """Load and setup ReconstructionFeatureExtractor"""
        model_config = self.config.models
        model_config_dict = OmegaConf.to_container(model_config, resolve=True)
        model_config_dict["device"] = self.device
        model_config_dict["cache_dir"] = str(self.cache_dir / "models")
        
        feature_extractor = load_image_feature_extractor(model_config_dict)
        logger.info(f"Loaded {model_config_dict.get('model_name')} reconstruction feature extractor")
        return feature_extractor

    def prepare_reconstruction_input_datasets_for_layer(
        self,
        reconstruction_pipeline: ReconstructionPipeline,
        train_source_loader: DataLoader,
        val_source_loader: DataLoader,
        test_source_loader: DataLoader,
        layer: int,
        image_feature_type: str,
    ) -> Tuple[ReconstructionDataset, ReconstructionDataset, ReconstructionDataset]:
        """
        Uses ReconstructionPipeline to extract image features for a specific layer
        and combine them with processed camera parameters, then creates datasets.
        """
        experiment_id = f"{self.config.models.model_name}_{self.config.experiment.name}_layer_{layer}"
        
        # Create datasets using the new API
        train_input_dataset = reconstruction_pipeline.create_dataset(
            dataloader=train_source_loader,
            layers=[layer],
            feature_type=image_feature_type,
            cache_key=f"{experiment_id}_train",
            force_recompute=self.config.get("force_recompute_processed_data", False)
        )
        
        val_input_dataset = reconstruction_pipeline.create_dataset(
            dataloader=val_source_loader,
            layers=[layer],
            feature_type=image_feature_type,
            cache_key=f"{experiment_id}_val",
            force_recompute=self.config.get("force_recompute_processed_data", False)
        )
        
        test_input_dataset = reconstruction_pipeline.create_dataset(
            dataloader=test_source_loader,
            layers=[layer],
            feature_type=image_feature_type,
            cache_key=f"{experiment_id}_test",
            force_recompute=self.config.get("force_recompute_processed_data", False)
        )
        
        return train_input_dataset, val_input_dataset, test_input_dataset

    def run_voxel_probe_experiment(
        self,
        train_processed_loader: DataLoader, 
        val_processed_loader: DataLoader,
        test_processed_loader: DataLoader,
        feature_dim: int,
        layer: int,
    ) -> Dict:
        """Run a single VoxelProbe experiment"""
        probe_type = "voxel"
        logger.info(
            f"Running VoxelProbe on layer {layer} (input_feature_dim: {feature_dim})"
        )

        probe_config = self.config.probing
        
        probe_config["input_dim"] = feature_dim
        probe_config["task_type"] = "voxel_reconstruction" 
        
        self.device = probe_config.get("device", self.device)

        probe = create_probe(probe_config)
        
        metrics_tracker = MetricsTracker()
        trainer = ProbeTrainer(
            probe, device=self.device, MetricsTracker=metrics_tracker
        )

        training_config = self.config.probing.get("training", {}) 
        optimizer_specific_config = probe_config.get("optimizer", training_config.get("optimizer", {}))
        scheduler_specific_config = probe_config.get("scheduler", training_config.get("scheduler", {}))

        optimizer = self.create_optimizer(probe, optimizer_specific_config)
        scheduler = self.create_scheduler(optimizer, scheduler_specific_config)

        epochs = training_config.get("epochs", 50) # Potentially more epochs for reconstruction
        early_stopping_patience = training_config.get("early_stopping_patience", 10)
        wandb_enabled = self.config.get("wandb", {}).get("enabled", False)

        best_model_state_dict, best_val_loss = trainer.train(
            epochs,
            optimizer,
            scheduler,
            early_stopping_patience,
            train_processed_loader,
            val_processed_loader,
            probe_type=probe_type, # Pass "voxel"
            layer=layer,
            wandb_enabled=wandb_enabled,
        )
        
        probe_filename = f"{self.config.models.model_name}_{probe_type}_layer_{layer}_probe.pth"
        probe_save_path = self.probe_save_dir / probe_filename
        
        torch.save({
            'model_state_dict': best_model_state_dict,
            'probe_config': probe_config, 
            'layer': layer,
            'probe_type': probe_type,
            'experiment_name': self.config.experiment.name,
            'model_name': self.config.models.model_name,
            'best_val_loss': best_val_loss,
            'input_feature_dim': feature_dim 
        }, probe_save_path)
        logger.info(f"Saved VoxelProbe for layer {layer} to {probe_save_path}")

        probe.load_state_dict(best_model_state_dict)
       
        test_metrics = trainer.evaluate(
            test_loader=test_processed_loader, 
            wandb_enabled=wandb_enabled, 
            probe_type=probe_type, 
            layer=layer
        )

        detailed_metrics = self._compute_detailed_metrics(probe, test_processed_loader) 

        total_epochs_trained = len(metrics_tracker.get_history("train"))

        results = {
            "train_history": metrics_tracker.get_history("train"),
            "val_history": metrics_tracker.get_history("val"),
            "test_metrics": test_metrics, 
            "detailed_metrics": detailed_metrics, 
            "best_epoch": metrics_tracker.best_epoch,
            "total_epochs": total_epochs_trained,
        }
        return results

    def create_optimizer(
        self, model: nn.Module, optimizer_config: Dict
    ) -> torch.optim.Optimizer:
        from hydra.utils import instantiate
        opt_config_copy = OmegaConf.create(optimizer_config) 
        if "_target_" not in opt_config_copy: 
             raise ValueError("Optimizer config must have a _target_ field")

        return instantiate(opt_config_copy, params=model.parameters())


    def create_scheduler(
        self, optimizer: torch.optim.Optimizer, scheduler_config: Dict
    ):
        if not scheduler_config or not scheduler_config.get("_target_"): 
            return None
        from hydra.utils import instantiate
        sched_config_copy = OmegaConf.create(scheduler_config)
        return instantiate(sched_config_copy, optimizer=optimizer)

    def _compute_detailed_metrics( 
        self, probe: nn.Module, test_loader: DataLoader 
    ) -> Dict:
        
        probe.to(self.device)
        probe.eval()
        all_predictions = [] 
        all_targets = []   

        with torch.no_grad():
            for batch in tqdm(test_loader, desc="Computing detailed metrics"):
                features = batch["processed_views"].to(self.device) 
                targets = batch["target_voxels"].to(self.device) 

                if probe.task_type == "voxel_reconstruction":
                    features = features.view(features.size(0), -1)

                outputs = probe(features) # Voxel logits: [B, 1, D, H, W]

                all_predictions.append(outputs.cpu()) 
                all_targets.append(targets.cpu())

        predictions_cat = torch.cat(all_predictions, dim=0)
        targets_cat = torch.cat(all_targets, dim=0)
        
        metrics = {}
        voxel_eval_metrics = compute_voxel_metrics(predictions_cat, targets_cat)
        metrics.update(voxel_eval_metrics)
        
        return metrics

    def save_results(self, results: Dict) -> str:
        import json
        results_file = self.results_dir / "reconstruction_results.json"
        serializable_results = self.make_json_serializable(results)
        combined_results = {
            "config": OmegaConf.to_container(self.config, resolve=True),
            "results": serializable_results,
        }
        with open(results_file, "w") as f:
            json.dump(combined_results, f, indent=2)
        logger.info(f"Reconstruction results saved to {results_file}")
        return str(results_file)

    def make_json_serializable(self, obj):
        if isinstance(obj, dict):
            return {k: self.make_json_serializable(v) for k, v in obj.items()}
        elif isinstance(obj, list):
            return [self.make_json_serializable(v) for v in obj]
        elif isinstance(obj, (torch.Tensor, np.ndarray)):
            return obj.tolist() if hasattr(obj, "tolist") else float(obj)
        elif isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, Path):
            return str(obj)
        else:
            return obj

# %% [markdown]
# ### Hydra Configuration Loading / Setup

# %%
from hydra import initialize, compose
from hydra.core.global_hydra import GlobalHydra
import os 
from pathlib import Path

CONFIG_PATH = "../configs"
CONFIG_NAME = "exp_supervisedVIT_reconstruction"  # Use the new restructured config with defaults

cfg: Optional[DictConfig] = None

if GlobalHydra.instance().is_initialized():
    logger.info("Clearing existing Hydra global state.")
    GlobalHydra.instance().clear()

try:
    project_root = Path(os.getcwd()).parent 
    data_dir_abs = project_root / "data" 
    os.environ["DATA_DIR"] = str(data_dir_abs)
    
    logger.info(f"Initializing Hydra with config_path: '{CONFIG_PATH}' relative to {os.getcwd()}")
    initialize(version_base=None, config_path=CONFIG_PATH, job_name="reconstruction_experiment")
    
    logger.info(f"Composing configuration with config_name: '{CONFIG_NAME}'")
    cfg = compose(config_name=CONFIG_NAME) 

except Exception as e:
    logger.error(f"Error initializing Hydra or loading configuration: {e}", exc_info=True)
    cfg = None 

if cfg:
    logger.info("Hydra configuration loaded successfully for reconstruction experiment.")
    logger.info(f"Experiment name: {cfg.experiment.name}")
    logger.info(f"Task type: {cfg.probing.task_type}")
    logger.info(f"Probe types: {cfg.probing.probe_types}")

else:
    logger.error("Failed to load Hydra configuration. Please check paths and config files.")

# Quick check for critical reconstruction settings
if cfg and cfg.probing.task_type != "voxel_reconstruction":
    logger.warning(f"Configured task_type is '{cfg.probing.task_type}', expected 'voxel_reconstruction' for this notebook.")
if cfg and "voxel" not in cfg.probing.probe_types:
    logger.warning(f"Configured probe_types are '{cfg.probing.probe_types}', 'voxel' probe might not run.")
# Out:
# 2025-06-06 18:16:16,097 - __main__ - INFO - Initializing Hydra with config_path: '../configs' relative to c:\Users\stunt\OneDrive\Documents\GitHub\LatentInvestigation\notebooks
# 2025-06-06 18:16:16,619 - __main__ - INFO - Composing configuration with config_name: 'exp_supervisedVIT_reconstruction'
# 2025-06-06 18:16:16,742 - __main__ - INFO - Hydra configuration loaded successfully for reconstruction experiment.
# 2025-06-06 18:16:16,743 - __main__ - INFO - Experiment name: phase2_supervisedVIT_voxel_reconstruction
# 2025-06-06 18:16:16,743 - __main__ - INFO - Task type: voxel_reconstruction
# 2025-06-06 18:16:16,743 - __main__ - INFO - Probe types: ['voxel']

# %% [markdown]
# ## Running the Reconstruction Experiment

# %%
reconstruction_results = None
if cfg:
    logger.info("Starting reconstruction experiment execution")
    experiment = ReconstructionExperiment(cfg)
else:
    logger.error("Configuration not loaded. Cannot start experiment.")
    experiment = None
# Out:
# 2025-06-06 18:16:16,758 - __main__ - INFO - Starting reconstruction experiment execution
# 2025-06-06 18:16:16,759 - __main__ - INFO - Using device: cuda
# 2025-06-06 18:16:17,100 - wandb.jupyter - ERROR - Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: rsen0811 (cse493g1_drn). Use `wandb login --relogin` to force relogin
# wandb version 0.20.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>c:\Users\stunt\OneDrive\Documents\GitHub\LatentInvestigation\notebooks\wandb\run-20250606_181618-ueasosy4</code>
# Syncing run <strong><a href='https://wandb.ai/cse493g1_drn/latent-investigation/runs/ueasosy4' target="_blank">phase2_supervisedVIT_voxel_reconstruction_reconstruction</a></strong> to <a href='https://wandb.ai/cse493g1_drn/latent-investigation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cse493g1_drn/latent-investigation' target="_blank">https://wandb.ai/cse493g1_drn/latent-investigation</a>
#  View run at <a href='https://wandb.ai/cse493g1_drn/latent-investigation/runs/ueasosy4' target="_blank">https://wandb.ai/cse493g1_drn/latent-investigation/runs/ueasosy4</a>

# %% [markdown]
# ### Load Source Data and Feature Extractor

# %%
if experiment:
    image_feature_extractor = experiment.load_reconstruction_feature_extractor()
    
    extraction_config = cfg.models.get("feature_extraction", {})
    layers_to_probe = extraction_config.get("layers", [0, 2, 5, 8, 11]) 
    image_feature_type = extraction_config.get("feature_type", "cls_token")

    train_source_loader, val_source_loader, test_source_loader = experiment.load_source_dataset()
    
    reconstruction_pipeline = ReconstructionPipeline(
        image_pipeline=image_feature_extractor,
        device=experiment.device,
        cache_dir=str(experiment.cache_dir / "processed_reconstruction_data")
    )
else:
    logger.error("Experiment not initialized. Skipping feature extractor and dataset loading.")
# Out:
# 2025-06-06 18:16:22,368 - src.models.model_loader - INFO - Loading HuggingFace model 'google/vit-base-patch16-224'
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.weight', 'vit.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-06-06 18:16:23,884 - src.models.reconstruction_feature_extractor - INFO - Loaded and froze supervised_vit on cuda.
# 2025-06-06 18:16:23,884 - __main__ - INFO - Loaded supervised_vit reconstruction feature extractor
# Created train DataLoader with 2451 samples, batch size 32.
# Created val DataLoader with 525 samples, batch size 32.
# Created test DataLoader with 525 samples, batch size 32.

# %% [markdown]
# ### Process Data and Train VoxelProbes for Each Layer

# %%
if experiment:
    reconstruction_results = {}

    if "voxel" not in cfg.probing.probe_types:
        logger.error(f"'voxel' not in configured probe_types: {cfg.probing.probe_types}. VoxelProbes will not be trained.")
    else:
        logger.info(f"Will train VoxelProbes for layers: {layers_to_probe}")

        for layer_idx in tqdm(layers_to_probe, desc="Processing Layers"):
            logger.info(f"Processing layer {layer_idx} for reconstruction...")

            # Use the updated method with new API
            train_input_ds, val_input_ds, test_input_ds = experiment.prepare_reconstruction_input_datasets_for_layer(
                reconstruction_pipeline=reconstruction_pipeline,
                train_source_loader=train_source_loader,
                val_source_loader=val_source_loader,
                test_source_loader=test_source_loader,
                layer=layer_idx,
                image_feature_type=image_feature_type,
            )
            
            logger.info(f"Layer {layer_idx}: Train Input Dataset size: {len(train_input_ds)}")
            logger.info(f"Layer {layer_idx}: Val Input Dataset size: {len(val_input_ds)}")
            logger.info(f"Layer {layer_idx}: Test Input Dataset size: {len(test_input_ds)}")

            # Create DataLoaders from the datasets
            processed_batch_size = cfg.training.get("batch_size", 32)
            
            train_processed_loader = DataLoader(
                train_input_ds,
                batch_size=processed_batch_size,
                shuffle=True,
                num_workers=cfg.get("num_workers", 4),
                pin_memory=True
            )
            
            val_processed_loader = DataLoader(
                val_input_ds,
                batch_size=processed_batch_size,
                shuffle=False,
                num_workers=cfg.get("num_workers", 4),
                pin_memory=True
            )
            
            test_processed_loader = DataLoader(
                test_input_ds,
                batch_size=processed_batch_size,
                shuffle=False,
                num_workers=cfg.get("num_workers", 4),
                pin_memory=True
            )

            # Get feature dimension from sample
            sample_processed_data = train_input_ds[0]["processed_views"]
            input_feature_dim_for_probe = sample_processed_data.numel() 
            logger.info(f"Input feature dimension for VoxelProbe at layer {layer_idx}: {input_feature_dim_for_probe} (Shape of sample: {sample_processed_data.shape})")

            logger.info(f"Running VoxelProbe on layer {layer_idx}...")
            probe_run_results = experiment.run_voxel_probe_experiment(
                train_processed_loader=train_processed_loader,
                val_processed_loader=val_processed_loader,
                test_processed_loader=test_processed_loader,
                feature_dim=input_feature_dim_for_probe,
                layer=layer_idx,
            )
            reconstruction_results[f"layer_{layer_idx}"] = {"voxel": probe_run_results}

else:
    logger.error("Experiment not initialized. Skipping layer processing and probe training.")
# Out:
# 2025-06-06 18:16:24,037 - __main__ - INFO - Will train VoxelProbes for layers: [2, 4, 6, 8, 10, 11]
# Processing Layers:   0%|          | 0/6 [00:00<?, ?it/s]2025-06-06 18:16:24,040 - __main__ - INFO - Processing layer 2 for reconstruction...
# 2025-06-06 18:16:24,041 - src.probing.base_pipeline - INFO - Processing 76 batches...
# It looks like you are trying to rescale already rescaled images. If the input images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again.
# 2025-06-06 18:27:19,913 - src.probing.base_pipeline - INFO - Saved cached data to cache\phase2_supervisedVIT_voxel_reconstruction\processed_reconstruction_data\supervised_vit_phase2_supervisedVIT_voxel_reconstruction_layer_2_train.pkl
# 2025-06-06 18:27:19,939 - src.probing.base_pipeline - INFO - Processing 17 batches...
# 2025-06-06 18:29:41,751 - src.probing.base_pipeline - INFO - Saved cached data to cache\phase2_supervisedVIT_voxel_reconstruction\processed_reconstruction_data\supervised_vit_phase2_supervisedVIT_voxel_reconstruction_layer_2_val.pkl
# 2025-06-06 18:29:41,756 - src.probing.base_pipeline - INFO - Processing 17 batches...
# 2025-06-06 18:31:59,067 - src.probing.base_pipeline - INFO - Saved cached data to cache\phase2_supervisedVIT_voxel_reconstruction\processed_reconstruction_data\supervised_vit_phase2_supervisedVIT_voxel_reconstruction_layer_2_test.pkl
# 2025-06-06 18:31:59,072 - __main__ - INFO - Layer 2: Train Input Dataset size: 2432
# 2025-06-06 18:31:59,073 - __main__ - INFO - Layer 2: Val Input Dataset size: 525
# 2025-06-06 18:31:59,073 - __main__ - INFO - Layer 2: Test Input Dataset size: 525
# 2025-06-06 18:31:59,077 - __main__ - INFO - Input feature dimension for VoxelProbe at layer 2: 18624 (Shape of sample: torch.Size([18624]))
# 2025-06-06 18:31:59,078 - __main__ - INFO - Running VoxelProbe on layer 2...
# 2025-06-06 18:31:59,079 - __main__ - INFO - Running VoxelProbe on layer 2 (input_feature_dim: 18624)
#
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:14<?, ?it/s, loss=0.669]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:14<08:40, 14.06s/it, loss=0.669]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:14<08:40, 14.06s/it, loss=0.646]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:14<03:32,  5.91s/it, loss=0.646]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:14<03:32,  5.91s/it, loss=0.581]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:14<01:55,  3.30s/it, loss=0.581]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:14<01:55,  3.30s/it, loss=0.531]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:14<01:10,  2.07s/it, loss=0.531]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:14<01:10,  2.07s/it, loss=0.486]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:14<00:46,  1.40s/it, loss=0.486]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:15<00:46,  1.40s/it, loss=0.448]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:15<00:31,  1.01it/s, loss=0.448]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:15<00:31,  1.01it/s, loss=0.424]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:15<00:22,  1.37it/s, loss=0.424]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:15<00:22,  1.37it/s, loss=0.4]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:15<00:16,  1.78it/s, loss=0.4]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:15<00:16,  1.78it/s, loss=0.379]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:15<00:12,  2.24it/s, loss=0.379]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:15<00:12,  2.24it/s, loss=0.373]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:15<00:10,  2.69it/s, loss=0.373]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:16<00:10,  2.69it/s, loss=0.37]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:16<00:08,  3.14it/s, loss=0.37]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:16<00:08,  3.14it/s, loss=0.355]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:16<00:07,  3.54it/s, loss=0.355]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:16<00:07,  3.54it/s, loss=0.348]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:16<00:06,  3.88it/s, loss=0.348]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:16<00:06,  3.88it/s, loss=0.341]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:16<00:05,  4.16it/s, loss=0.341]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:16<00:05,  4.16it/s, loss=0.333]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:16<00:05,  4.38it/s, loss=0.333]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:17<00:05,  4.38it/s, loss=0.331]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:17<00:04,  4.57it/s, loss=0.331]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:17<00:04,  4.57it/s, loss=0.327]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:17<00:04,  4.69it/s, loss=0.327]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:17<00:04,  4.69it/s, loss=0.323]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:17<00:04,  4.80it/s, loss=0.323]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:17<00:04,  4.80it/s, loss=0.319]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:17<00:03,  4.87it/s, loss=0.319]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:17<00:03,  4.87it/s, loss=0.316]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:17<00:03,  4.91it/s, loss=0.316]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:18<00:03,  4.91it/s, loss=0.312]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:18<00:03,  4.94it/s, loss=0.312]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:18<00:03,  4.94it/s, loss=0.31]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:18<00:03,  4.96it/s, loss=0.31]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:18<00:03,  4.96it/s, loss=0.308]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:18<00:03,  4.99it/s, loss=0.308]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:18<00:03,  4.99it/s, loss=0.307]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:18<00:02,  5.00it/s, loss=0.307]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:18<00:02,  5.00it/s, loss=0.304]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:18<00:02,  5.00it/s, loss=0.304]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:19<00:02,  5.00it/s, loss=0.3]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:19<00:02,  5.03it/s, loss=0.3]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:19<00:02,  5.03it/s, loss=0.301]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:19<00:02,  5.03it/s, loss=0.301]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:19<00:02,  5.03it/s, loss=0.301]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:19<00:01,  5.02it/s, loss=0.301]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:19<00:01,  5.02it/s, loss=0.3]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:19<00:01,  5.04it/s, loss=0.3]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:19<00:01,  5.04it/s, loss=0.3]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:19<00:01,  5.06it/s, loss=0.3]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:20<00:01,  5.06it/s, loss=0.299]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:20<00:01,  5.06it/s, loss=0.299]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:20<00:01,  5.06it/s, loss=0.298]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:20<00:01,  5.04it/s, loss=0.298]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:20<00:01,  5.04it/s, loss=0.297]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:20<00:00,  5.06it/s, loss=0.297]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:20<00:00,  5.06it/s, loss=0.298]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:20<00:00,  5.05it/s, loss=0.298]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:20<00:00,  5.05it/s, loss=0.298]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:20<00:00,  5.06it/s, loss=0.298]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:21<00:00,  5.06it/s, loss=0.296]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:21<00:00,  5.06it/s, loss=0.296]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:21<00:00,  5.06it/s, loss=0.295]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:21<00:00,  5.06it/s, loss=0.295]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:21<00:00,  5.06it/s, loss=0.293]
# Epoch 1/30 [Train Lyr:2 Prb:voxel]: 100%|██████████| 38/38 [00:21<00:00,  5.07it/s, loss=0.293]
#
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.258]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.27s/it, loss=0.258]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.27s/it, loss=0.253]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.42s/it, loss=0.253]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.42s/it, loss=0.257]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.42s/it, loss=0.261]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.74it/s, loss=0.261]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.74it/s, loss=0.256]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.74it/s, loss=0.256]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.256]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.257]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.261]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.264]
# Epoch 1/30 [Val Lyr:2 Prb:voxel]: 100%|██████████| 9/9 [00:03<00:00,  5.52it/s, loss=0.264]
#                                                                                            2025-06-06 18:32:26,211 - src.probing.probes - INFO - Epoch 1/30 Lyr:2 Prb:voxel - Train Loss: 0.2935, Val Loss: 0.2644
#
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:11<?, ?it/s, loss=0.249]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:22, 11.97s/it, loss=0.249]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:12<07:22, 11.97s/it, loss=0.25]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<03:01,  5.04s/it, loss=0.25]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<03:01,  5.04s/it, loss=0.261]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:39,  2.83s/it, loss=0.261]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:39,  2.83s/it, loss=0.249]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<01:00,  1.79s/it, loss=0.249]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<01:00,  1.79s/it, loss=0.25]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:40,  1.22s/it, loss=0.25]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:40,  1.22s/it, loss=0.251]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:12<00:27,  1.15it/s, loss=0.251]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:13<00:27,  1.15it/s, loss=0.247]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:13<00:20,  1.54it/s, loss=0.247]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:13<00:20,  1.54it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:13<00:15,  1.97it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:13<00:15,  1.97it/s, loss=0.25]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:11,  2.44it/s, loss=0.25]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:11,  2.44it/s, loss=0.251]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:09,  2.90it/s, loss=0.251]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:09,  2.90it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:13<00:08,  3.35it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:14<00:08,  3.35it/s, loss=0.255]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:14<00:06,  3.72it/s, loss=0.255]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:14<00:06,  3.72it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:14<00:06,  4.04it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:14<00:06,  4.04it/s, loss=0.255]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:14<00:05,  4.31it/s, loss=0.255]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:14<00:05,  4.31it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:05,  4.52it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:05,  4.52it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:14<00:04,  4.68it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:15<00:04,  4.68it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:15<00:04,  4.78it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:15<00:04,  4.78it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:15<00:04,  4.85it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:15<00:04,  4.85it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:15<00:03,  4.91it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:15<00:03,  4.91it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:15<00:03,  4.94it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:15<00:03,  4.94it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:15<00:03,  4.97it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:16<00:03,  4.97it/s, loss=0.251]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:16<00:03,  5.00it/s, loss=0.251]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:16<00:03,  5.00it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:16<00:02,  5.01it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:16<00:02,  5.01it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:16<00:02,  5.03it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:16<00:02,  5.03it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:16<00:02,  5.04it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:16<00:02,  5.04it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:16<00:02,  5.04it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:17<00:02,  5.04it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:17<00:02,  5.04it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:17<00:02,  5.04it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:17<00:01,  5.05it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:17<00:01,  5.05it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:17<00:01,  5.04it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:17<00:01,  5.04it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:17<00:01,  5.05it/s, loss=0.252]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:17<00:01,  5.05it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:17<00:01,  5.06it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:18<00:01,  5.06it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:18<00:01,  5.07it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:18<00:01,  5.07it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:18<00:00,  5.08it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:18<00:00,  5.08it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:18<00:00,  5.08it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:18<00:00,  5.08it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:18<00:00,  5.08it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:18<00:00,  5.08it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:18<00:00,  5.07it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:19<00:00,  5.07it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:19<00:00,  5.06it/s, loss=0.253]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:19<00:00,  5.06it/s, loss=0.254]
# Epoch 2/30 [Train Lyr:2 Prb:voxel]: 100%|██████████| 38/38 [00:19<00:00,  5.08it/s, loss=0.254]
#
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.252]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:25,  3.23s/it, loss=0.252]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:25,  3.23s/it, loss=0.248]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.248]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.252]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.255]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.74it/s, loss=0.255]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.74it/s, loss=0.251]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.74it/s, loss=0.251]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.251]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.251]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.255]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.258]
# Epoch 2/30 [Val Lyr:2 Prb:voxel]: 100%|██████████| 9/9 [00:03<00:00,  5.54it/s, loss=0.258]
#                                                                                            2025-06-06 18:32:50,158 - src.probing.probes - INFO - Epoch 2/30 Lyr:2 Prb:voxel - Train Loss: 0.2544, Val Loss: 0.2583
#
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:11<?, ?it/s, loss=0.279]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:16, 11.80s/it, loss=0.279]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:16, 11.80s/it, loss=0.272]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:11<02:59,  4.97s/it, loss=0.272]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<02:59,  4.97s/it, loss=0.273]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:37,  2.79s/it, loss=0.273]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:37,  2.79s/it, loss=0.272]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<01:00,  1.77s/it, loss=0.272]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<01:00,  1.77s/it, loss=0.272]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:39,  1.20s/it, loss=0.272]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:39,  1.20s/it, loss=0.268]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:12<00:27,  1.16it/s, loss=0.268]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:12<00:27,  1.16it/s, loss=0.267]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:12<00:19,  1.55it/s, loss=0.267]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:13<00:19,  1.55it/s, loss=0.265]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:13<00:15,  1.99it/s, loss=0.265]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:13<00:15,  1.99it/s, loss=0.264]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:11,  2.46it/s, loss=0.264]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:11,  2.46it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:09,  2.93it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:09,  2.93it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:13<00:08,  3.36it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:13<00:08,  3.36it/s, loss=0.264]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:13<00:06,  3.74it/s, loss=0.264]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:14<00:06,  3.74it/s, loss=0.264]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:14<00:06,  4.06it/s, loss=0.264]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:14<00:06,  4.06it/s, loss=0.263]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:14<00:05,  4.32it/s, loss=0.263]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:14<00:05,  4.32it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:05,  4.51it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:05,  4.51it/s, loss=0.26]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:14<00:04,  4.66it/s, loss=0.26]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:14<00:04,  4.66it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:14<00:04,  4.77it/s, loss=0.261]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:15<00:04,  4.77it/s, loss=0.26]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:15<00:04,  4.85it/s, loss=0.26]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:15<00:04,  4.85it/s, loss=0.259]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:15<00:03,  4.93it/s, loss=0.259]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:15<00:03,  4.93it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:15<00:03,  4.98it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:15<00:03,  4.98it/s, loss=0.255]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:15<00:03,  5.00it/s, loss=0.255]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:15<00:03,  5.00it/s, loss=0.259]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:15<00:03,  4.99it/s, loss=0.259]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:16<00:03,  4.99it/s, loss=0.26]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:16<00:02,  5.02it/s, loss=0.26]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:16<00:02,  5.02it/s, loss=0.259]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:16<00:02,  5.01it/s, loss=0.259]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:16<00:02,  5.01it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:16<00:02,  5.04it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:16<00:02,  5.04it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:16<00:02,  5.03it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:16<00:02,  5.03it/s, loss=0.256]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:16<00:02,  5.03it/s, loss=0.256]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:17<00:02,  5.03it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:17<00:01,  5.04it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:17<00:01,  5.04it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:17<00:01,  5.05it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:17<00:01,  5.05it/s, loss=0.258]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:17<00:01,  5.06it/s, loss=0.258]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:17<00:01,  5.06it/s, loss=0.258]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:17<00:01,  5.05it/s, loss=0.258]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:17<00:01,  5.05it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:17<00:01,  5.06it/s, loss=0.257]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:18<00:01,  5.06it/s, loss=0.258]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:18<00:00,  5.05it/s, loss=0.258]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:18<00:00,  5.05it/s, loss=0.256]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:18<00:00,  5.07it/s, loss=0.256]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:18<00:00,  5.07it/s, loss=0.256]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:18<00:00,  5.07it/s, loss=0.256]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:18<00:00,  5.07it/s, loss=0.255]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:18<00:00,  5.08it/s, loss=0.255]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:18<00:00,  5.08it/s, loss=0.254]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:18<00:00,  5.08it/s, loss=0.254]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:19<00:00,  5.08it/s, loss=0.253]
# Epoch 3/30 [Train Lyr:2 Prb:voxel]: 100%|██████████| 38/38 [00:19<00:00,  5.09it/s, loss=0.253]
#
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.254]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.29s/it, loss=0.254]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.29s/it, loss=0.249]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:10,  1.44s/it, loss=0.249]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:10,  1.44s/it, loss=0.253]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:10,  1.44s/it, loss=0.257]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.73it/s, loss=0.257]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.73it/s, loss=0.253]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.73it/s, loss=0.253]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.253]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.254]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.258]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.05it/s, loss=0.262]
# Epoch 3/30 [Val Lyr:2 Prb:voxel]: 100%|██████████| 9/9 [00:03<00:00,  5.53it/s, loss=0.262]
#                                                                                            2025-06-06 18:33:14,002 - src.probing.probes - INFO - Epoch 3/30 Lyr:2 Prb:voxel - Train Loss: 0.2534, Val Loss: 0.2620
#
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:11<?, ?it/s, loss=0.271]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:14, 11.75s/it, loss=0.271]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:14, 11.75s/it, loss=0.266]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:11<02:58,  4.95s/it, loss=0.266]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<02:58,  4.95s/it, loss=0.273]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:37,  2.78s/it, loss=0.273]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:37,  2.78s/it, loss=0.258]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<00:59,  1.76s/it, loss=0.258]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<00:59,  1.76s/it, loss=0.253]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:39,  1.20s/it, loss=0.253]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:39,  1.20s/it, loss=0.256]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:12<00:27,  1.17it/s, loss=0.256]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:12<00:27,  1.17it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:12<00:19,  1.56it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:13<00:19,  1.56it/s, loss=0.251]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:13<00:15,  1.99it/s, loss=0.251]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:13<00:15,  1.99it/s, loss=0.25]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:11,  2.46it/s, loss=0.25]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:11,  2.46it/s, loss=0.256]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:09,  2.92it/s, loss=0.256]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:09,  2.92it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:13<00:08,  3.35it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:13<00:08,  3.35it/s, loss=0.257]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:13<00:06,  3.73it/s, loss=0.257]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:14<00:06,  3.73it/s, loss=0.257]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:14<00:06,  4.06it/s, loss=0.257]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:14<00:06,  4.06it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:14<00:05,  4.32it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:14<00:05,  4.32it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:05,  4.51it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:05,  4.51it/s, loss=0.253]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:14<00:04,  4.67it/s, loss=0.253]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:14<00:04,  4.67it/s, loss=0.252]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:14<00:04,  4.76it/s, loss=0.252]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:15<00:04,  4.76it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:15<00:04,  4.85it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:15<00:04,  4.85it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:15<00:03,  4.90it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:15<00:03,  4.90it/s, loss=0.252]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:15<00:03,  4.95it/s, loss=0.252]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:15<00:03,  4.95it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:15<00:03,  4.99it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:15<00:03,  4.99it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:15<00:03,  5.01it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:16<00:03,  5.01it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:16<00:02,  5.02it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:16<00:02,  5.02it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:16<00:02,  5.02it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:16<00:02,  5.02it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:16<00:02,  5.01it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:16<00:02,  5.01it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:16<00:02,  5.02it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:16<00:02,  5.02it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:16<00:02,  5.02it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:17<00:02,  5.02it/s, loss=0.253]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:17<00:01,  5.01it/s, loss=0.253]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:17<00:01,  5.01it/s, loss=0.252]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:17<00:01,  5.01it/s, loss=0.252]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:17<00:01,  5.01it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:17<00:01,  5.02it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:17<00:01,  5.02it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:17<00:01,  5.03it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:17<00:01,  5.03it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:17<00:01,  5.04it/s, loss=0.255]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:18<00:01,  5.04it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:18<00:00,  5.03it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:18<00:00,  5.03it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:18<00:00,  5.06it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:18<00:00,  5.06it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:18<00:00,  5.03it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:18<00:00,  5.03it/s, loss=0.256]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:18<00:00,  5.05it/s, loss=0.256]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:18<00:00,  5.05it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:18<00:00,  5.04it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:19<00:00,  5.04it/s, loss=0.254]
# Epoch 4/30 [Train Lyr:2 Prb:voxel]: 100%|██████████| 38/38 [00:19<00:00,  5.04it/s, loss=0.254]
#
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.252]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:25,  3.20s/it, loss=0.252]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:25,  3.20s/it, loss=0.247]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.247]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.25]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.254]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.77it/s, loss=0.254]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.77it/s, loss=0.25]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.77it/s, loss=0.25]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.11it/s, loss=0.25]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.11it/s, loss=0.25]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.11it/s, loss=0.254]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.11it/s, loss=0.257]
# Epoch 4/30 [Val Lyr:2 Prb:voxel]: 100%|██████████| 9/9 [00:03<00:00,  5.64it/s, loss=0.257]
#                                                                                            2025-06-06 18:33:37,803 - src.probing.probes - INFO - Epoch 4/30 Lyr:2 Prb:voxel - Train Loss: 0.2537, Val Loss: 0.2574
#
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:12<?, ?it/s, loss=0.22]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:12<07:44, 12.56s/it, loss=0.22]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:12<07:44, 12.56s/it, loss=0.24]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<03:10,  5.29s/it, loss=0.24]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<03:10,  5.29s/it, loss=0.242]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:43,  2.96s/it, loss=0.242]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:13<01:43,  2.96s/it, loss=0.245]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:13<01:03,  1.87s/it, loss=0.245]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:13<01:03,  1.87s/it, loss=0.245]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:13<00:41,  1.27s/it, loss=0.245]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:13<00:41,  1.27s/it, loss=0.25]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:13<00:28,  1.11it/s, loss=0.25]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  16%|█▌        | 6/38 [00:13<00:28,  1.11it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:13<00:20,  1.49it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  18%|█▊        | 7/38 [00:13<00:20,  1.49it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:13<00:15,  1.91it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  21%|██        | 8/38 [00:14<00:15,  1.91it/s, loss=0.251]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:14<00:12,  2.37it/s, loss=0.251]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  24%|██▎       | 9/38 [00:14<00:12,  2.37it/s, loss=0.252]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:14<00:09,  2.83it/s, loss=0.252]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  26%|██▋       | 10/38 [00:14<00:09,  2.83it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:14<00:08,  3.28it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  29%|██▉       | 11/38 [00:14<00:08,  3.28it/s, loss=0.252]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:14<00:07,  3.66it/s, loss=0.252]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  32%|███▏      | 12/38 [00:14<00:07,  3.66it/s, loss=0.251]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:14<00:06,  3.99it/s, loss=0.251]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  34%|███▍      | 13/38 [00:15<00:06,  3.99it/s, loss=0.251]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:15<00:05,  4.25it/s, loss=0.251]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  37%|███▋      | 14/38 [00:15<00:05,  4.25it/s, loss=0.248]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:15<00:05,  4.46it/s, loss=0.248]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  39%|███▉      | 15/38 [00:15<00:05,  4.46it/s, loss=0.248]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:15<00:04,  4.62it/s, loss=0.248]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  42%|████▏     | 16/38 [00:15<00:04,  4.62it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:15<00:04,  4.75it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  45%|████▍     | 17/38 [00:15<00:04,  4.75it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:15<00:04,  4.84it/s, loss=0.246]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  47%|████▋     | 18/38 [00:16<00:04,  4.84it/s, loss=0.247]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:16<00:03,  4.90it/s, loss=0.247]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  50%|█████     | 19/38 [00:16<00:03,  4.90it/s, loss=0.249]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:16<00:03,  4.94it/s, loss=0.249]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  53%|█████▎    | 20/38 [00:16<00:03,  4.94it/s, loss=0.25]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:16<00:03,  4.97it/s, loss=0.25]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  55%|█████▌    | 21/38 [00:16<00:03,  4.97it/s, loss=0.253]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:16<00:03,  5.00it/s, loss=0.253]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  58%|█████▊    | 22/38 [00:16<00:03,  5.00it/s, loss=0.252]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:16<00:02,  5.00it/s, loss=0.252]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  61%|██████    | 23/38 [00:17<00:02,  5.00it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:17<00:02,  5.03it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  63%|██████▎   | 24/38 [00:17<00:02,  5.03it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:17<00:02,  5.03it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  66%|██████▌   | 25/38 [00:17<00:02,  5.03it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:17<00:02,  5.04it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  68%|██████▊   | 26/38 [00:17<00:02,  5.04it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:17<00:02,  5.04it/s, loss=0.254]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  71%|███████   | 27/38 [00:17<00:02,  5.04it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:17<00:01,  5.03it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  74%|███████▎  | 28/38 [00:18<00:01,  5.03it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:18<00:01,  5.01it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  76%|███████▋  | 29/38 [00:18<00:01,  5.01it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:18<00:01,  5.02it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  79%|███████▉  | 30/38 [00:18<00:01,  5.02it/s, loss=0.256]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:18<00:01,  5.01it/s, loss=0.256]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  82%|████████▏ | 31/38 [00:18<00:01,  5.01it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:18<00:01,  5.02it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  84%|████████▍ | 32/38 [00:18<00:01,  5.02it/s, loss=0.256]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:18<00:00,  5.01it/s, loss=0.256]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  87%|████████▋ | 33/38 [00:19<00:00,  5.01it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:19<00:00,  5.03it/s, loss=0.257]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  89%|████████▉ | 34/38 [00:19<00:00,  5.03it/s, loss=0.256]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:19<00:00,  5.03it/s, loss=0.256]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  92%|█████████▏| 35/38 [00:19<00:00,  5.03it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:19<00:00,  5.04it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  95%|█████████▍| 36/38 [00:19<00:00,  5.04it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:19<00:00,  5.06it/s, loss=0.255]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]:  97%|█████████▋| 37/38 [00:19<00:00,  5.06it/s, loss=0.253]
# Epoch 5/30 [Train Lyr:2 Prb:voxel]: 100%|██████████| 38/38 [00:19<00:00,  5.05it/s, loss=0.253]
#
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.254]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.28s/it, loss=0.254]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.28s/it, loss=0.249]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.28s/it, loss=0.253]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  33%|███▎      | 3/9 [00:03<00:05,  1.11it/s, loss=0.253]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  33%|███▎      | 3/9 [00:03<00:05,  1.11it/s, loss=0.256]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  33%|███▎      | 3/9 [00:03<00:05,  1.11it/s, loss=0.251]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  56%|█████▌    | 5/9 [00:03<00:01,  2.15it/s, loss=0.251]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  56%|█████▌    | 5/9 [00:03<00:01,  2.15it/s, loss=0.251]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  56%|█████▌    | 5/9 [00:03<00:01,  2.15it/s, loss=0.252]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  56%|█████▌    | 5/9 [00:03<00:01,  2.15it/s, loss=0.255]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  89%|████████▉ | 8/9 [00:03<00:00,  4.07it/s, loss=0.255]
# Epoch 5/30 [Val Lyr:2 Prb:voxel]:  89%|████████▉ | 8/9 [00:03<00:00,  4.07it/s, loss=0.259]
#                                                                                            2025-06-06 18:34:02,407 - src.probing.probes - INFO - Epoch 5/30 Lyr:2 Prb:voxel - Train Loss: 0.2534, Val Loss: 0.2592
#
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   0%|          | 0/38 [00:11<?, ?it/s, loss=0.267]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:22, 11.95s/it, loss=0.267]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   3%|▎         | 1/38 [00:12<07:22, 11.95s/it, loss=0.249]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<03:01,  5.04s/it, loss=0.249]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   5%|▌         | 2/38 [00:12<03:01,  5.04s/it, loss=0.25]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:39,  2.83s/it, loss=0.25]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:39,  2.83s/it, loss=0.256]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<01:00,  1.79s/it, loss=0.256]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:  11%|█         | 4/38 [00:12<01:00,  1.79s/it, loss=0.246]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:40,  1.22s/it, loss=0.246]
# Epoch 6/30 [Train Lyr:2 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:40,  1.22s/it, loss=0.254]
# ...
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  61%|██████    | 23/38 [00:15<00:02,  6.15it/s, loss=0.25]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  63%|██████▎   | 24/38 [00:15<00:02,  6.11it/s, loss=0.25]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  63%|██████▎   | 24/38 [00:15<00:02,  6.11it/s, loss=0.25]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  66%|██████▌   | 25/38 [00:15<00:02,  6.19it/s, loss=0.25]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  66%|██████▌   | 25/38 [00:15<00:02,  6.19it/s, loss=0.25]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  68%|██████▊   | 26/38 [00:15<00:01,  6.25it/s, loss=0.25]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  68%|██████▊   | 26/38 [00:15<00:01,  6.25it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  71%|███████   | 27/38 [00:15<00:01,  6.25it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  71%|███████   | 27/38 [00:15<00:01,  6.25it/s, loss=0.254]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  74%|███████▎  | 28/38 [00:15<00:01,  6.22it/s, loss=0.254]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  74%|███████▎  | 28/38 [00:15<00:01,  6.22it/s, loss=0.253]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  76%|███████▋  | 29/38 [00:15<00:01,  6.27it/s, loss=0.253]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  76%|███████▋  | 29/38 [00:16<00:01,  6.27it/s, loss=0.252]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  79%|███████▉  | 30/38 [00:16<00:01,  6.27it/s, loss=0.252]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  79%|███████▉  | 30/38 [00:16<00:01,  6.27it/s, loss=0.252]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  82%|████████▏ | 31/38 [00:16<00:01,  6.21it/s, loss=0.252]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  82%|████████▏ | 31/38 [00:16<00:01,  6.21it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  84%|████████▍ | 32/38 [00:16<00:00,  6.24it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  84%|████████▍ | 32/38 [00:16<00:00,  6.24it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  87%|████████▋ | 33/38 [00:16<00:00,  6.21it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  87%|████████▋ | 33/38 [00:16<00:00,  6.21it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  89%|████████▉ | 34/38 [00:16<00:00,  6.22it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  89%|████████▉ | 34/38 [00:16<00:00,  6.22it/s, loss=0.252]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  92%|█████████▏| 35/38 [00:16<00:00,  6.18it/s, loss=0.252]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  92%|█████████▏| 35/38 [00:17<00:00,  6.18it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  95%|█████████▍| 36/38 [00:17<00:00,  6.20it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  95%|█████████▍| 36/38 [00:17<00:00,  6.20it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  97%|█████████▋| 37/38 [00:17<00:00,  6.20it/s, loss=0.251]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]:  97%|█████████▋| 37/38 [00:17<00:00,  6.20it/s, loss=0.252]
# Epoch 29/30 [Train Lyr:11 Prb:voxel]: 100%|██████████| 38/38 [00:17<00:00,  6.22it/s, loss=0.252]
#
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.251]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.31s/it, loss=0.251]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.31s/it, loss=0.246]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  11%|█         | 1/9 [00:03<00:26,  3.31s/it, loss=0.25]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  33%|███▎      | 3/9 [00:03<00:05,  1.10it/s, loss=0.25]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  33%|███▎      | 3/9 [00:03<00:05,  1.10it/s, loss=0.253]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  33%|███▎      | 3/9 [00:03<00:05,  1.10it/s, loss=0.249]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  56%|█████▌    | 5/9 [00:03<00:01,  2.14it/s, loss=0.249]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  56%|█████▌    | 5/9 [00:03<00:01,  2.14it/s, loss=0.249]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  56%|█████▌    | 5/9 [00:03<00:01,  2.14it/s, loss=0.249]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  78%|███████▊  | 7/9 [00:03<00:00,  3.44it/s, loss=0.249]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  78%|███████▊  | 7/9 [00:03<00:00,  3.44it/s, loss=0.253]
# Epoch 29/30 [Val Lyr:11 Prb:voxel]:  78%|███████▊  | 7/9 [00:03<00:00,  3.44it/s, loss=0.256]
#                                                                                              2025-06-06 20:54:42,776 - src.probing.probes - INFO - Epoch 29/30 Lyr:11 Prb:voxel - Train Loss: 0.2519, Val Loss: 0.2563
#
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   0%|          | 0/38 [00:11<?, ?it/s, loss=0.237]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:17, 11.83s/it, loss=0.237]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   3%|▎         | 1/38 [00:11<07:17, 11.83s/it, loss=0.229]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   5%|▌         | 2/38 [00:11<02:58,  4.97s/it, loss=0.229]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   5%|▌         | 2/38 [00:12<02:58,  4.97s/it, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:37,  2.77s/it, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:   8%|▊         | 3/38 [00:12<01:37,  2.77s/it, loss=0.254]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  11%|█         | 4/38 [00:12<00:59,  1.74s/it, loss=0.254]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  11%|█         | 4/38 [00:12<00:59,  1.74s/it, loss=0.257]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:38,  1.17s/it, loss=0.257]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  13%|█▎        | 5/38 [00:12<00:38,  1.17s/it, loss=0.255]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  16%|█▌        | 6/38 [00:12<00:26,  1.20it/s, loss=0.255]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  16%|█▌        | 6/38 [00:12<00:26,  1.20it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  18%|█▊        | 7/38 [00:12<00:18,  1.64it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  18%|█▊        | 7/38 [00:12<00:18,  1.64it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  21%|██        | 8/38 [00:12<00:14,  2.13it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  21%|██        | 8/38 [00:13<00:14,  2.13it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:10,  2.69it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  24%|██▎       | 9/38 [00:13<00:10,  2.69it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:08,  3.24it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  26%|██▋       | 10/38 [00:13<00:08,  3.24it/s, loss=0.258]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  29%|██▉       | 11/38 [00:13<00:07,  3.80it/s, loss=0.258]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  29%|██▉       | 11/38 [00:13<00:07,  3.80it/s, loss=0.267]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  32%|███▏      | 12/38 [00:13<00:06,  4.30it/s, loss=0.267]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  32%|███▏      | 12/38 [00:13<00:06,  4.30it/s, loss=0.266]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  34%|███▍      | 13/38 [00:13<00:05,  4.72it/s, loss=0.266]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  34%|███▍      | 13/38 [00:13<00:05,  4.72it/s, loss=0.265]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  37%|███▋      | 14/38 [00:13<00:04,  5.05it/s, loss=0.265]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  37%|███▋      | 14/38 [00:14<00:04,  5.05it/s, loss=0.263]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:04,  5.32it/s, loss=0.263]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  39%|███▉      | 15/38 [00:14<00:04,  5.32it/s, loss=0.261]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  42%|████▏     | 16/38 [00:14<00:03,  5.55it/s, loss=0.261]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  42%|████▏     | 16/38 [00:14<00:03,  5.55it/s, loss=0.264]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  45%|████▍     | 17/38 [00:14<00:03,  5.71it/s, loss=0.264]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  45%|████▍     | 17/38 [00:14<00:03,  5.71it/s, loss=0.264]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  47%|████▋     | 18/38 [00:14<00:03,  5.85it/s, loss=0.264]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  47%|████▋     | 18/38 [00:14<00:03,  5.85it/s, loss=0.262]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  50%|█████     | 19/38 [00:14<00:03,  5.94it/s, loss=0.262]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  50%|█████     | 19/38 [00:14<00:03,  5.94it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  53%|█████▎    | 20/38 [00:14<00:03,  5.98it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  53%|█████▎    | 20/38 [00:15<00:03,  5.98it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  55%|█████▌    | 21/38 [00:15<00:02,  6.06it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  55%|█████▌    | 21/38 [00:15<00:02,  6.06it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  58%|█████▊    | 22/38 [00:15<00:02,  6.12it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  58%|█████▊    | 22/38 [00:15<00:02,  6.12it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  61%|██████    | 23/38 [00:15<00:02,  6.05it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  61%|██████    | 23/38 [00:15<00:02,  6.05it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  63%|██████▎   | 24/38 [00:15<00:02,  6.08it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  63%|██████▎   | 24/38 [00:15<00:02,  6.08it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  66%|██████▌   | 25/38 [00:15<00:02,  6.07it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  66%|██████▌   | 25/38 [00:15<00:02,  6.07it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  68%|██████▊   | 26/38 [00:15<00:01,  6.08it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  68%|██████▊   | 26/38 [00:16<00:01,  6.08it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  71%|███████   | 27/38 [00:16<00:01,  6.11it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  71%|███████   | 27/38 [00:16<00:01,  6.11it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  74%|███████▎  | 28/38 [00:16<00:01,  6.14it/s, loss=0.26]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  74%|███████▎  | 28/38 [00:16<00:01,  6.14it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  76%|███████▋  | 29/38 [00:16<00:01,  6.06it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  76%|███████▋  | 29/38 [00:16<00:01,  6.06it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  79%|███████▉  | 30/38 [00:16<00:01,  6.11it/s, loss=0.259]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  79%|███████▉  | 30/38 [00:16<00:01,  6.11it/s, loss=0.257]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  82%|████████▏ | 31/38 [00:16<00:01,  6.18it/s, loss=0.257]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  82%|████████▏ | 31/38 [00:16<00:01,  6.18it/s, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  84%|████████▍ | 32/38 [00:16<00:00,  6.21it/s, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  84%|████████▍ | 32/38 [00:17<00:00,  6.21it/s, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  87%|████████▋ | 33/38 [00:17<00:00,  6.25it/s, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  87%|████████▋ | 33/38 [00:17<00:00,  6.25it/s, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  89%|████████▉ | 34/38 [00:17<00:00,  6.30it/s, loss=0.256]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  89%|████████▉ | 34/38 [00:17<00:00,  6.30it/s, loss=0.255]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  92%|█████████▏| 35/38 [00:17<00:00,  6.28it/s, loss=0.255]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  92%|█████████▏| 35/38 [00:17<00:00,  6.28it/s, loss=0.254]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  95%|█████████▍| 36/38 [00:17<00:00,  6.31it/s, loss=0.254]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  95%|█████████▍| 36/38 [00:17<00:00,  6.31it/s, loss=0.253]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  97%|█████████▋| 37/38 [00:17<00:00,  6.29it/s, loss=0.253]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]:  97%|█████████▋| 37/38 [00:17<00:00,  6.29it/s, loss=0.252]
# Epoch 30/30 [Train Lyr:11 Prb:voxel]: 100%|██████████| 38/38 [00:17<00:00,  6.25it/s, loss=0.252]
#
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.251]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  11%|█         | 1/9 [00:03<00:25,  3.23s/it, loss=0.251]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  11%|█         | 1/9 [00:03<00:25,  3.23s/it, loss=0.246]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.246]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.25]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  22%|██▏       | 2/9 [00:03<00:09,  1.41s/it, loss=0.254]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.75it/s, loss=0.254]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.75it/s, loss=0.249]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  44%|████▍     | 4/9 [00:03<00:02,  1.75it/s, loss=0.249]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.04it/s, loss=0.249]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.04it/s, loss=0.25]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.04it/s, loss=0.253]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]:  67%|██████▋   | 6/9 [00:03<00:00,  3.04it/s, loss=0.257]
# Epoch 30/30 [Val Lyr:11 Prb:voxel]: 100%|██████████| 9/9 [00:03<00:00,  5.47it/s, loss=0.257]
#                                                                                              2025-06-06 20:55:05,645 - src.probing.probes - INFO - Epoch 30/30 Lyr:11 Prb:voxel - Train Loss: 0.2518, Val Loss: 0.2568
# 2025-06-06 20:55:07,626 - __main__ - INFO - Saved VoxelProbe for layer 11 to cache\phase2_supervisedVIT_voxel_reconstruction\probes\supervised_vit_voxel_layer_11_probe.pth
#
# Evaluating Lyr:11 Prb:voxel:   0%|          | 0/9 [00:00<?, ?it/s]
# Evaluating Lyr:11 Prb:voxel:   0%|          | 0/9 [00:03<?, ?it/s, loss=0.225]
# Evaluating Lyr:11 Prb:voxel:  11%|█         | 1/9 [00:03<00:27,  3.45s/it, loss=0.225]
# Evaluating Lyr:11 Prb:voxel:  11%|█         | 1/9 [00:03<00:27,  3.45s/it, loss=0.214]
# Evaluating Lyr:11 Prb:voxel:  11%|█         | 1/9 [00:03<00:27,  3.45s/it, loss=0.218]
# Evaluating Lyr:11 Prb:voxel:  33%|███▎      | 3/9 [00:03<00:05,  1.06it/s, loss=0.218]
# Evaluating Lyr:11 Prb:voxel:  33%|███▎      | 3/9 [00:03<00:05,  1.06it/s, loss=0.225]
# Evaluating Lyr:11 Prb:voxel:  33%|███▎      | 3/9 [00:03<00:05,  1.06it/s, loss=0.238]
# Evaluating Lyr:11 Prb:voxel:  56%|█████▌    | 5/9 [00:03<00:01,  2.07it/s, loss=0.238]
# Evaluating Lyr:11 Prb:voxel:  56%|█████▌    | 5/9 [00:03<00:01,  2.07it/s, loss=0.244]
# Evaluating Lyr:11 Prb:voxel:  56%|█████▌    | 5/9 [00:03<00:01,  2.07it/s, loss=0.241]
# Evaluating Lyr:11 Prb:voxel:  56%|█████▌    | 5/9 [00:03<00:01,  2.07it/s, loss=0.249]
# Evaluating Lyr:11 Prb:voxel:  89%|████████▉ | 8/9 [00:03<00:00,  3.91it/s, loss=0.249]
# Evaluating Lyr:11 Prb:voxel:  89%|████████▉ | 8/9 [00:03<00:00,  3.91it/s, loss=0.243]
#                                                                                       2025-06-06 20:55:12,253 - src.probing.probes - INFO - Test Metrics (Lyr:11 Prb:voxel): {'loss': 0.24280981719493866, 'voxel_iou': 0.044941842555999756, 'voxel_precision': 0.5451182723045349, 'voxel_recall': 0.04857878014445305, 'voxel_f1': 0.24831357598304749}
#
# Computing detailed metrics:   0%|          | 0/9 [00:00<?, ?it/s]
# Computing detailed metrics:  11%|█         | 1/9 [00:03<00:26,  3.25s/it]
# Computing detailed metrics:  22%|██▏       | 2/9 [00:03<00:09,  1.42s/it]
# Computing detailed metrics:  44%|████▍     | 4/9 [00:03<00:02,  1.77it/s]
# Computing detailed metrics:  67%|██████▋   | 6/9 [00:03<00:00,  3.08it/s]
# Computing detailed metrics: 100%|██████████| 9/9 [00:04<00:00,  2.14it/s]
# Processing Layers: 100%|██████████| 6/6 [2:38:52<00:00, 1588.79s/it]

# %%
if experiment and reconstruction_results:
    logger.info("Saving reconstruction experiment results...")
    result_file_path = experiment.save_results(reconstruction_results)
    logger.info(f"Results saved to: {result_file_path}")
else:
    logger.warning("No results to save or experiment not run.")
# Out:
# 2025-06-06 20:55:16,956 - __main__ - INFO - Saving reconstruction experiment results...
# 2025-06-06 20:55:16,972 - __main__ - INFO - Reconstruction results saved to results\phase2_supervisedVIT_voxel_reconstruction\reconstruction_results.json
# 2025-06-06 20:55:16,973 - __main__ - INFO - Results saved to: results\phase2_supervisedVIT_voxel_reconstruction\reconstruction_results.json

# %% [markdown]
# ### Analyze and Visualize Results

# %%
from src.analysis.layer_analysis import analyze_experiment_results

if experiment and reconstruction_results and 'result_file_path' in locals():
    logger.info("Analyzing reconstruction results...")

    analyze_experiment_results(
        results_file=result_file_path,
        output_dir=Path(result_file_path).parent
    )
else:
    logger.warning("No results to analyze or result file path not available.")
# Out:
# 2025-06-06 20:55:17,008 - __main__ - INFO - Analyzing reconstruction results...
# 2025-06-06 20:55:22,293 - src.analysis.layer_analysis - INFO - Analysis report saved to results\phase2_supervisedVIT_voxel_reconstruction\layer_analysis_report.json
